# %% [markdown]
# 1. Program to create a Student class and display details

# %%
class Student:
    def __init__(self, name, age, course):
        self.name = name
        self.age = age
        self.course = course

    def display(self):
        print("Name:", self.name)
        print("Age:", self.age)
        print("Course:", self.course)

s1 = Student("Swayam Ramdin", 19, "Engineering")
s1.display()
# Out:
# Name: Swayam Ramdin
# Age: 19
# Course: Engineering

# %% [markdown]
# 2. Program using constructor to initialize student details

# %%
class Student:
    def __init__(self, name, age, marks):
        self.name = name
        self.age = age
        self.marks = marks

    def display(self):
        print("Name:", self.name)
        print("Age:", self.age)
        print("Marks:", self.marks)

s1 = Student("Swayam Ramdin", 19, 79)
s1.display()
# Out:
# Name: Swayam Ramdin
# Age: 19
# Marks: 79

# %% [markdown]
# 3. Program to take multiple student objects

# %%
class Student:
    def __init__(self, name, age, course):
        self.name = name
        self.age = age
        self.course = course

    def display(self):
        print("Name:", self.name)
        print("Age:", self.age)
        print("Course:", self.course)
        print()

students = []

n = int(input("Enter number of students: "))

for i in range(n):
    name = input("Enter name: ")
    age = int(input("Enter age: "))
    course = input("Enter course: ")
    students.append(Student(name, age, course))

for s in students:
    s.display()
# Out:
# Enter number of students:  1
# Enter name:  Swayam Ramdin
# Enter age:  19
# Enter course:  PPP
# Name: Swayam Ramdin
# Age: 19
# Course: PPP

# %%
class Student:
    def __init__(self):
        self.name = "Icebox"

s1 = Student()
print(s1.name)
# Out:
# Icebox

# %%
class Student:
    def show(self):
        print("Hello")

obj = Student()
obj.show()
# Out:
# Hello
